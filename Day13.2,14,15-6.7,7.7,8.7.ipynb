# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import model_selection
from sklearn import linear_model
from sklearn import metrics
from sklearn import preprocessing
from sklearn import tree
from sklearn import feature_selection
from sklearn import ensemble #for RandomForest

# %%
df=pd.read_csv('IRIS.csv')
df["type"]=df["species"].replace({"Iris-setosa":1,"Iris-versicolor":2,"Iris-virginica":3})
df
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1428\3402023232.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["type"]=df["species"].replace({"Iris-setosa":1,"Iris-versicolor":2,"Iris-virginica":3})
#      sepal_length  sepal_width  petal_length  petal_width         species  \
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# ...

# %%
df['type'].value_counts()
# Out:
# type
# 1    50
# 2    50
# 3    50
# Name: count, dtype: int64

# %%
X=df.drop(["species","type"],axis=1)
y=df["type"]
Xtrain,Xtest,ytrain,ytest=model_selection.train_test_split(X,y,test_size=.15,random_state=42)

# %%
treemodel=tree.DecisionTreeClassifier(random_state=42)
treemodel.fit(Xtrain,ytrain) #binary tree model
predtrain=treemodel.predict(Xtrain)
predtest=treemodel.predict(Xtest)

# %%
from sklearn import metrics

def printscores(act, pred):
    print("accuracy :", metrics.accuracy_score(act, pred))
    print("recall (macro):", metrics.recall_score(act, pred, average="macro"))
    print("precision (macro):", metrics.precision_score(act, pred, average="macro"))
    print("f1 (macro):", metrics.f1_score(act, pred, average="macro"))

# %%
print("TRAINING MERICS:")
printscores(ytrain,predtrain)
print("==================")
print("TEST METRICS:")
printscores(ytest,predtest)
# Out:
# TRAINING MERICS:
# accuracy : 1.0
# recall (macro): 1.0
# precision (macro): 1.0
# f1 (macro): 1.0
# ...
# TEST METRICS:
# accuracy : 1.0
# recall (macro): 1.0
# precision (macro): 1.0
# f1 (macro): 1.0

# %% [markdown]
# <h3> PIMA DIABETICS

# %%
df=pd.read_csv('diabetes.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df=df.drop(["SkinThickness","Insulin"],axis=1)

# %%
df=df[df['Pregnancies']!=0]
df=df[df['BloodPressure']!=0]
df=df[df['BMI']!=0]
X=df.drop("Outcome",axis=1)
y=df["Outcome"]

Xtrain,Xtest,ytrain,ytest=model_selection.train_test_split(X,y,test_size=.25,random_state=42)

# %%
model=tree.DecisionTreeClassifier(random_state=42)
model.fit(Xtrain,ytrain)
predtrain=model.predict(Xtrain)
predtest=model.predict(Xtest)
print("TRAINING MERICS:")
printscores(ytrain,predtrain)
print("==================")
print("TEST METRICS:")
printscores(ytest,predtest)
# Out:
# TRAINING MERICS:
# accuracy : 1.0
# recall (macro): 1.0
# precision (macro): 1.0
# f1 (macro): 1.0
# ...
# TEST METRICS:
# accuracy : 0.6708860759493671
# recall (macro): 0.6491293765212507
# precision (macro): 0.6346121345276322
# f1 (macro): 0.6374227714033539

# %%
#OVERFIT MODEL

# %% [markdown]
# <H3> LOGISTIC REGRESSION MODEL

# %%
model=linear_model.LogisticRegression()
model.fit(Xtrain,ytrain)
predtrain=model.predict(Xtrain)
predtest=model.predict(Xtest)
print("TRAINING MERICS:")
printscores(ytrain,predtrain)
print("==================")
print("TEST METRICS:")
printscores(ytest,predtest)
# Out:
# TRAINING MERICS:
# accuracy : 0.7648305084745762
# recall (macro): 0.7236657576938059
# precision (macro): 0.7502015470094782
# f1 (macro): 0.7320910824866153
# ...
# TEST METRICS:
# accuracy : 0.7721518987341772
# recall (macro): 0.7281407976034451
# precision (macro): 0.7335633505846272
# f1 (macro): 0.7306818181818182

# %%
pd.Series(np.abs(model.coef_[0]),index=Xtrain.columns).sort_values(ascending=False)
# Out:
# DiabetesPedigreeFunction    0.703769
# Pregnancies                 0.131840
# BMI                         0.111268
# Glucose                     0.027607
# Age                         0.019740
# BloodPressure               0.006952
# dtype: float64

# %%
model=tree.DecisionTreeClassifier(random_state=42)
model.fit(Xtrain,ytrain)
predtrain=model.predict(Xtrain)
predtest=model.predict(Xtest)
print("TRAINING MERICS:")
printscores(ytrain,predtrain)
print("==================")
print("TEST METRICS:")
printscores(ytest,predtest)
# Out:
# TRAINING MERICS:
# accuracy : 1.0
# recall (macro): 1.0
# precision (macro): 1.0
# f1 (macro): 1.0
# ...
# TEST METRICS:
# accuracy : 0.6708860759493671
# recall (macro): 0.6491293765212507
# precision (macro): 0.6346121345276322
# f1 (macro): 0.6374227714033539

# %%
model.feature_importances_
# Out:
# array([0.05893195, 0.3253823 , 0.10767063, 0.14460538, 0.20625416,
#        0.15715558])

# %%
pd.Series(model.feature_importances_,index=Xtrain.columns).sort_values(ascending=False)
# Out:
# Glucose                     0.325382
# DiabetesPedigreeFunction    0.206254
# Age                         0.157156
# BMI                         0.144605
# BloodPressure               0.107671
# Pregnancies                 0.058932
# dtype: float64

# %% [markdown]
# * We see which columns are important according to weight.

# %% [markdown]
# # CONSTRAINING - To prevent Overfit model, we need to change the model now. RFE is used

# %%
#recall is more in dec tree than logistic reg, so it has better chances of giving a good model

# %% [markdown]
# <h3> Recursive Feature Elimination using LR

# %%
#Creating a model using most important columns.We are using Logistic Regression to find the model.RFE class used for dimensionality reduction.

# %%
model=linear_model.LogisticRegression()
rfeobj=feature_selection.RFE(estimator=model,n_features_to_select=4) #RFE->class under feature_selelction
rfeobj.fit(Xtrain,ytrain)
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=4)

# %%
rfeobj.support_
# Out:
# array([ True,  True, False,  True,  True, False])

# %%
Xtrain.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'BMI',
#        'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
print("SIGNIFICANT COLUMNS :",Xtrain.columns[rfeobj.support_])
# Out:
# SIGNIFICANT COLUMNS : Index(['Pregnancies', 'Glucose', 'BMI', 'DiabetesPedigreeFunction'], dtype='object')

# %%
arr=rfeobj.transform(Xtrain) #returns a numpy array that needs to be changed back to dataframe
Xtrain1=pd.DataFrame(arr,columns=Xtrain.columns[rfeobj.support_],index=Xtrain.index)
#updating columns according to the new columns from rfeobj, index updated according to the Xtrain index so that the selected index is recovered
Xtest1=pd.DataFrame(rfeobj.transform(Xtest),columns=Xtest.columns[rfeobj.support_],index=Xtest.index)

# %%
Xtrain1[:10]
# Out:
#      Pregnancies  Glucose   BMI  DiabetesPedigreeFunction
# 375         12.0    140.0  39.2                     0.528
# 722          1.0    149.0  29.3                     0.349
# 234          3.0     74.0  29.7                     0.293
# 593          2.0     82.0  28.5                     1.699
# 315          2.0    112.0  34.1                     0.315
# 161          7.0    102.0  37.2                     0.204
# 278          5.0    114.0  24.9                     0.744
# 368          3.0     81.0  27.5                     0.306
# 209          7.0    184.0  35.5                     0.355
# 12          10.0    139.0  27.1                     1.441

# %% [markdown]
# <h3> Recursive Feature Eliminstion using DT

# %%
#using Dec Tree model is formed now
model=tree.DecisionTreeClassifier(random_state=42)
rfeobj=feature_selection.RFE(estimator=model,n_features_to_select=4) #RFE->class under feature_selelction
rfeobj.fit(Xtrain,ytrain)
print("SIGNIFICANT COLUMNS :",Xtrain.columns[rfeobj.support_])
arr=rfeobj.transform(Xtrain) #returns a numpy array that needs to be changed back to dataframe
Xtrain1=pd.DataFrame(arr,columns=Xtrain.columns[rfeobj.support_],index=Xtrain.index)
#updating columns according to the new columns from rfeobj, index updated according to the Xtrain index so that the selected index is recovered
Xtest1=pd.DataFrame(rfeobj.transform(Xtest),columns=Xtest.columns[rfeobj.support_],index=Xtest.index)
# Out:
# SIGNIFICANT COLUMNS : Index(['Glucose', 'BMI', 'DiabetesPedigreeFunction', 'Age'], dtype='object')

# %%
#using Xtrain1 model
model=tree.DecisionTreeClassifier(random_state=42)
model.fit(Xtrain1,ytrain) 
predtrain=model.predict(Xtrain1)
predtest=model.predict(Xtest1)
print("TRAINING MERICS:")
printscores(ytrain,predtrain)
print("==================")
print("TEST METRICS:")
printscores(ytest,predtest)
# Out:
# TRAINING MERICS:
# accuracy : 1.0
# recall (macro): 1.0
# precision (macro): 1.0
# f1 (macro): 1.0
# ...
# TEST METRICS:
# accuracy : 0.6962025316455697
# recall (macro): 0.673094926043812
# precision (macro): 0.6582776921759972
# f1 (macro): 0.6623931623931625

# %%
model=tree.DecisionTreeClassifier(random_state=42,max_depth=6)
model.fit(Xtrain1,ytrain) 
predtrain=model.predict(Xtrain1)
predtest=model.predict(Xtest1)
print("TRAINING MERICS:")
printscores(ytrain,predtrain)
print("==================")
print("TEST METRICS:")
printscores(ytest,predtest)
# Out:
# TRAINING MERICS:
# accuracy : 0.8453389830508474
# recall (macro): 0.8032917802882742
# precision (macro): 0.858985590778098
# f1 (macro): 0.8200308166409862
# ...
# TEST METRICS:
# accuracy : 0.7151898734177216
# recall (macro): 0.6475379142482681
# precision (macro): 0.6617405582922824
# f1 (macro): 0.6527472527472528

# %%
model=tree.DecisionTreeClassifier(random_state=42,min_samples_split=20)
model.fit(Xtrain1,ytrain) 
predtrain=model.predict(Xtrain1)
predtest=model.predict(Xtest1)
print("TRAINING MERICS:")
printscores(ytrain,predtrain)
print("==================")
print("TEST METRICS:")
printscores(ytest,predtest)
# Out:
# TRAINING MERICS:
# accuracy : 0.8813559322033898
# recall (macro): 0.862290611608882
# precision (macro): 0.8773125608568646
# f1 (macro): 0.8688029860821569
# ...
# TEST METRICS:
# accuracy : 0.7088607594936709
# recall (macro): 0.6710353866317169
# precision (macro): 0.6641509433962265
# f1 (macro): 0.6670331684075499

# %% [markdown]
# <h3> 8.7.23

# %% [markdown]
# <h2>Hyper Parameter Tuning

# %%
#GridsearchCV-> class used to tune the parameters

# %%
#Step 1: Create dictionary
grid={ "max_depth":[8,9,10,11,12] }  # param_grid, key== hyperparameter name
model=tree.DecisionTreeClassifier(random_state=42) #estimator
gobj=model_selection.GridSearchCV(estimator=model,param_grid=grid,cv=5,scoring="recall",n_jobs=-1,return_train_score=True)
gobj.fit(Xtrain,ytrain) ## VERY INTENSIVE AND CPU CONSUMING TASK BEGINS
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [8, 9, 10, 11, 12]},
#              return_train_score=True, scoring='recall')

# %%
print(gobj.best_params_) # we see it works best on 8,maybe it will have better with previous data, so we check with 3-8
# Out:
# {'max_depth': 12}

# %%
print(gobj.best_score_)
# Out:
# 0.5705882352941176

# %%
bestmodel=gobj.best_estimator_ # directly selects the best parameter sets after tuning and creates new best model

# %%
predtest=bestmodel.predict(Xtest)
predtrain=bestmodel.predict(Xtrain)

# %%
printscores(ytest,predtest)
# Out:
# accuracy : 0.6835443037974683
# recall (macro): 0.6526867627785059
# precision (macro): 0.6416536390481153
# f1 (macro): 0.6451033243486073

# %%
printscores(ytrain,predtrain)
# Out:
# accuracy : 0.9915254237288136
# recall (macro): 0.9895208414491624
# precision (macro): 0.9920895989974938
# f1 (macro): 0.9907825102036831

# %%
grid={ "max_depth":[3,4,5,6,7],"min_samples_split":[30,40,50,60]}  # param_grid, key== hyperparameter name
model=tree.DecisionTreeClassifier(random_state=42) #estimator
gobj=model_selection.GridSearchCV(estimator=model,param_grid=grid,cv=5,scoring="recall",n_jobs=-1,return_train_score=True)
gobj.fit(Xtrain,ytrain)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [3, 4, 5, 6, 7],
#                          'min_samples_split': [30, 40, 50, 60]},
#              return_train_score=True, scoring='recall')

# %%
print(gobj.best_params_)
# Out:
# {'max_depth': 7, 'min_samples_split': 40}

# %%
print(gobj.best_score_)
# Out:
# 0.6647058823529413

# %%
griddf=pd.DataFrame(gobj.cv_results_)

# %%
griddf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean_fit_time            20 non-null     float64
#  1   std_fit_time             20 non-null     float64
#  2   mean_score_time          20 non-null     float64
#  3   std_score_time           20 non-null     float64
#  4   param_max_depth          20 non-null     int64
#  5   param_min_samples_split  20 non-null     int64
#  6   params                   20 non-null     object
#  7   split0_test_score        20 non-null     float64
#  8   split1_test_score        20 non-null     float64
#  9   split2_test_score        20 non-null     float64
#  10  split3_test_score        20 non-null     float64
#  11  split4_test_score        20 non-null     float64
#  12  mean_test_score          20 non-null     float64
#  13  std_test_score           20 non-null     float64
# ...

# %%
griddf[:5]
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.005289      0.000294         0.005498        0.000778
# 1       0.005474      0.001260         0.010526        0.007532
# 2       0.005636      0.001077         0.012345        0.008652
# 3       0.004996      0.001986         0.011623        0.005899
# 4       0.007533      0.004885         0.008074        0.005096
#
#    param_max_depth  param_min_samples_split  \
# 0                3                       30
# 1                3                       40
# 2                3                       50
# 3                3                       60
# 4                4                       30
#
#                                       params  split0_test_score  \
# 0  {'max_depth': 3, 'min_samples_split': 30}           0.411765
# 1  {'max_depth': 3, 'min_samples_split': 40}           0.411765
# 2  {'max_depth': 3, 'min_samples_split': 50}           0.411765
# ...

# %%
griddf[["params","mean_train_score","mean_test_score"]]
# Out:
#                                        params  mean_train_score  \
# 0   {'max_depth': 3, 'min_samples_split': 30}          0.480882
# 1   {'max_depth': 3, 'min_samples_split': 40}          0.489706
# 2   {'max_depth': 3, 'min_samples_split': 50}          0.489706
# 3   {'max_depth': 3, 'min_samples_split': 60}          0.489706
# 4   {'max_depth': 4, 'min_samples_split': 30}          0.729412
# 5   {'max_depth': 4, 'min_samples_split': 40}          0.745588
# 6   {'max_depth': 4, 'min_samples_split': 50}          0.745588
# 7   {'max_depth': 4, 'min_samples_split': 60}          0.757353
# 8   {'max_depth': 5, 'min_samples_split': 30}          0.657353
# 9   {'max_depth': 5, 'min_samples_split': 40}          0.666176
# 10  {'max_depth': 5, 'min_samples_split': 50}          0.666176
# 11  {'max_depth': 5, 'min_samples_split': 60}          0.688235
# 12  {'max_depth': 6, 'min_samples_split': 30}          0.714706
# 13  {'max_depth': 6, 'min_samples_split': 40}          0.725000
# ...

# %% [markdown]
# <h2> RANDOM FOREST

# %%
model=ensemble.RandomForestClassifier(random_state=42,n_estimators=200,n_jobs=-1) #n_estimators->no of internal trees

# %%
model.fit(Xtrain,ytrain)
# Out:
# RandomForestClassifier(n_estimators=200, n_jobs=-1, random_state=42)

# %%
len(model.estimators_)
# Out:
# 200

# %%
predtest=model.predict(Xtest)
predtrain=model.predict(Xtrain)

# %%
printscores(ytrain,predtrain)
# Out:
# accuracy : 1.0
# recall (macro): 1.0
# precision (macro): 1.0
# f1 (macro): 1.0
